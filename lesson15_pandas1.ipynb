# %%
import os
import pandas as pd

# 1. УЗНАТЬ ТЕКУЩИЙ ПУТЬ
current_dir = os.getcwd() 
print(f"Сейчас блокнот работает здесь: {current_dir}")

# 2. ЧТО ТАКОЕ r'' (Raw String)
# Буква 'r' перед кавычками отключает спецсимволы (например, \n или \t).
# Без неё Python выдаст ошибку SyntaxError на путях Windows.

# 3. ИМПОРТ ИЗ ЗАГРУЗОК (Пример)
# Используем r'' для корректной обработки обратных слэшей \
path = r'C:\Users\xenia\Downloads\archive (1)\2019.csv'

# Загрузка данных (замените 'data.csv' на ваше имя файла)
df = pd.read_csv(path) 

print(f"Путь для импорта сформирован: {path}")
# Out:
# Сейчас блокнот работает здесь: C:\Users\xenia
# Путь для импорта сформирован: C:\Users\xenia\Downloads\archive (1)\2019.csv

# %%
# ТЕОРИЯ: Поиск строки по значению (Фильтрация)

# 1. Основной синтаксис: df[условие]
# Внутри скобок пишем: Название_Таблицы['Название_Колонки'] == 'Искомое_Значение'
# row = df[df['ID'] == 'A123']

# 2. Вывод без индекса (только данные):
# .values превращает строку таблицы в чистый массив данных
# print(row.values)

# 3. Поиск по всей таблице (если колонка неизвестна):
# .isin(['значение']) ищет везде, .any(axis=1) находит нужную строку
# full_search = df[df.isin(['уникальное_слово']).any(axis=1)]

# ИТОГ: Чтобы увидеть всю строку, достаточно:
# df[df['колонки'] == 'значение']

display(df)
row = df[df['Country or region'] == 'Russia']
row
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...

# %%
# Вспомните урок, посвященный документации библиотек, и попробуйте самостоятельно найти способ показать все строки в таблице.
with pd.option_context('display.max_rows', None):
    display(df) 
    pass
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# 5               6               Switzerland  7.480           1.452
# 6               7                    Sweden  7.343           1.387
# 7               8               New Zealand  7.307           1.303
# 8               9                    Canada  7.278           1.365
# 9              10                   Austria  7.246           1.376
# 10             11                 Australia  7.228           1.372
# 11             12                Costa Rica  7.167           1.034
# 12             13                    Israel  7.139           1.276
# ...

# %%
display(df)
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  156 non-null    int64
#  1   Country or region             156 non-null    object
#  2   Score                         156 non-null    float64
#  3   GDP per capita                156 non-null    float64
#  4   Social support                156 non-null    float64
#  5   Healthy life expectancy       156 non-null    float64
#  6   Freedom to make life choices  156 non-null    float64
#  7   Generosity                    156 non-null    float64
#  8   Perceptions of corruption     156 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 11.1+ KB

# %%
# Вопрос 1.
# Поработаем с данными за 2018 год. Загрузите новый датасет. Используйте код df=pd.read_csv('2018.csv') 
# Сколько строк в датасете?
os.getcwd()
path = r'C:\Users\xenia\Downloads\archive (1)\2018.csv'
df_2018 = pd.read_csv(path)
(df_2018[df_2018['Country or region']=='France'])['Score']
# Out:
# 22    6.489
# Name: Score, dtype: float64

# %%
countries = ['Italy','Spain','Greece']
df_filter = df_2018[df_2018['Country or region'].isin(countries)]
df_filter
# Out:
#     Overall rank Country or region  Score  GDP per capita  Social support  \
# 35            36             Spain  6.310           1.251           1.538
# 46            47             Italy  6.000           1.264           1.501
# 78            79            Greece  5.358           1.154           1.202
#
#     Healthy life expectancy  Freedom to make life choices  Generosity  \
# 35                    0.965                         0.449       0.142
# 46                    0.946                         0.281       0.137
# 78                    0.879                         0.131       0.000
#
#     Perceptions of corruption
# 35                      0.074
# 46                      0.028
# 78                      0.044

# %%
# Отфильтруйте данные и найдите строки, которые соответствуют всем трем условиям одновременно (логическое И):
# вклад GDP per capita меньше 1
# вклад Social support меньше 1
# страна входит в топ-100 по индексу счастья
# Чему равен самый высокий индекс счастья в вашей выборке? Определите подходящую строку визуально.
df_filter2 = df_2018[
    (df_2018['GDP per capita']<1) & 
    (df_2018['Social support']<1) & 
    (df_2018['Overall rank'] <= 100)]
df_filter2
# Out:
#     Overall rank Country or region  Score  GDP per capita  Social support  \
# 74            75          Pakistan  5.472           0.652           0.810
# 84            85           Morocco  5.254           0.779           0.797
# 97            98           Somalia  4.982           0.000           0.712
# 98            99          Cameroon  4.975           0.535           0.891
#
#     Healthy life expectancy  Freedom to make life choices  Generosity  \
# 74                    0.424                         0.334       0.216
# 84                    0.669                         0.460       0.026
# 97                    0.115                         0.674       0.238
# 98                    0.182                         0.454       0.183
#
#     Perceptions of corruption
# 74                      0.113
# 84                      0.074
# 97                      0.282
# 98                      0.043

# %%
# отфильтруйте данные и выведите строки, которые соответствуют хотя бы одному из следующих условий (логическое ИЛИ):
# вклад GDP per capita больше 1,4 И вклад Social support больше 1,4
# страна входит в топ-10 по индексу счастья
# Какой самый низкий индекс счастья в этом наборе данных? Определите подходящую строку визуально.
df_filter3 = df_2018[
    ((df_2018['GDP per capita']>1.4) &
    (df_2018['Social support']>1.4)) |
    (df_2018['Overall rank']<11)
]
df_filter3
# Out:
#     Overall rank Country or region  Score  GDP per capita  Social support  \
# 0              1           Finland  7.632           1.305           1.592
# 1              2            Norway  7.594           1.456           1.582
# 2              3           Denmark  7.555           1.351           1.590
# 3              4           Iceland  7.495           1.343           1.644
# 4              5       Switzerland  7.487           1.420           1.549
# 5              6       Netherlands  7.441           1.361           1.488
# 6              7            Canada  7.328           1.330           1.532
# 7              8       New Zealand  7.324           1.268           1.601
# 8              9            Sweden  7.314           1.355           1.501
# 9             10         Australia  7.272           1.340           1.573
# 13            14           Ireland  6.977           1.448           1.583
# 16            17        Luxembourg  6.910           1.576           1.520
# ...

# %%
# Составьте короткий отчет по следующим странам Южной Европы: Испания, Италия, Греция, Португалия. Включите в него:
# Место в рейтинге
# Название страны
# Значение индекса счастья
# Разность между наивысшим уровнем счастья в этом году (7.632) и уровнем счастья данной страны
# % вклада GDP per capita в уровень счастья
# % вклада Social Support в уровень счастья
# Значения в последних трех столбцах должны быть округлены до одного знака после запятой.

# Чтобы рассчитать % вклада GDP per capita в уровень счастья, разделите значение вклада GDP per capita на значение 
# индекса счастья (Score) и умножьте на 100. Аналогично сделайте для расчета % вклада Social Support в уровень счастья.

countries2 = ['Spain','Portugal','Greece','Italy']
df2 = df_2018[df_2018['Country or region'].isin(countries2)]
df2['Diff'] = (7.632-df2['Score']).round(1)
df2['GDP percentage'] = (df2['GDP per capita'] / df2['Score'] * 100).round(1)
df2['Socsup percentage'] = (df2['Social support'] / df2['Score'] * 100).round(1)
df3 = df2.drop(['GDP per capita','Social support','Healthy life expectancy','Freedom to make life choices','Generosity','Perceptions of corruption',
    ],axis=1)
df3
# Out:
# C:\Users\xenia\AppData\Local\Temp\ipykernel_4896\1197982086.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Diff'] = (7.632-df2['Score']).round(1)
# C:\Users\xenia\AppData\Local\Temp\ipykernel_4896\1197982086.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['GDP percentage'] = (df2['GDP per capita'] / df2['Score'] * 100).round(1)
# C:\Users\xenia\AppData\Local\Temp\ipykernel_4896\1197982086.py:17: SettingWithCopyWarning:
# ...

# %%
# Нам нужно сделать отчет по пяти крупнейшим странам мира: России, Канаде, США, Китаю и Бразилии. В отчете должны быть следующие данные:
# Overall rank — место страны в общем рейтинге счастья.
# Country or region — название страны или региона.
# Score — значение индекса счастья.
# Часть индекса, не объясненная шестью параметрами (часть Дистопии).
# Доля индекса, не объясненная шестью параметрами (доля Дистопии).

path = r'C:\Users\xenia\Downloads\archive (1)\2019.csv'
df = pd.read_csv(path) 

countries = ['Russia','Canada','United States','China','Brazil']
df1 = df[df['Country or region'].isin(countries)]

factors = [
    'GDP per capita', 'Social support', 'Healthy life expectancy', 
    'Freedom to make life choices', 'Generosity', 'Perceptions of corruption'
]
df1['dyst_part'] = (df1['Score'] - df1[factors].sum(axis=1)).round(2)
df1['dyst_share'] = ((df1['Score'] - df1[factors].sum(axis=1))/df1['Score']*100).round(2)
df69 = df1.drop(['GDP per capita','Social support','Healthy life expectancy','Freedom to make life choices','Generosity','Perceptions of corruption'],axis=1)
df69
# Out:
# C:\Users\xenia\AppData\Local\Temp\ipykernel_4896\3231462975.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['dyst_part'] = (df1['Score'] - df1[factors].sum(axis=1)).round(2)
# C:\Users\xenia\AppData\Local\Temp\ipykernel_4896\3231462975.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['dyst_share'] = ((df1['Score'] - df1[factors].sum(axis=1))/df1['Score']*100).round(2)
#     Overall rank Country or region  Score  dyst_part  dyst_share
# ...
